# %% [markdown]
# <a href="https://colab.research.google.com/github/AI-Cultural-Heritage-Lab/llm_sanitization/blob/main/Sentence_Tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentence Embeddings
#
# - Author: Ulysses Pascal
# - Date: May 9, 2025
# - Description: Creating sentence by sentence embedding for all sentences in USHMM and ChatGPT data. The goal is to be able to sentences on a scale from positive to negative and compare overall, how different the sources are in tone.
# - goals:
# - tone classifier (very negative, somewhat negative, neutral, somewhat positive/optimisitic, very postive/optimistic)
# - get average positivity score across each source
# - create a graph that shows average (or stacked??) positivity accross  all docs for each percent of the document. ie x axis: 0 -> 100% of document (hypothesis: end of the document tends to have a positive uptick for gpt)
# - see if similar sentences content wise are similar tone wise.

# %%
#@title Mount Google Drive
import gspread
from google.colab import auth
from gspread_dataframe import get_as_dataframe
import pandas as pd


# Mount gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title Create a Base Directory for the Project

import os
BASE_DIR = f'/content/drive/MyDrive/AI and Cultural Heritage Lab/Current Projects/LLM Language Sanitization Project/Experiments   Data Analysis/11 Compare Sentences — Ulysses'

# Create the base directory if it doesn't exist
os.makedirs(BASE_DIR, exist_ok=True)

# %%
#@title Import Data
import pandas as pd

def read_gsheet(sheet_id, gid, *args, **kwargs):
    """
    Read a Google Sheet into a DataFrame.
    Accepts all the same arguments as pd.read_csv()
    """
    url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv&gid={gid}"
    df = pd.read_csv(url, *args, **kwargs)
    return df


# Import Combined Data from Google Sheets
sheet_id = "1_qAn-BNXdIzotr_bXXF2dAjJfa7pDFH1Q84Y9fEBby4"
gid = "1499249206"  # gid for combined_data_v6

df = read_gsheet(sheet_id, gid)
df.head()
# Out:
#    id       location  translated_query      query_type  \
# 0   0  United States               NaN         Factual
# 1   1  United States               NaN         Factual
# 2   2  United States               NaN         Factual
# 3   3  United States               NaN  Interpretative
# 4   4  United States               NaN         Factual
#
#                                  query_thematic_tags  \
# 0  ['Holocaust', 'World War II', 'History', 'Geno...
# 1  ['Genocide', 'Armenian history', 'World War I'...
# 2  ['Holocaust', 'History', 'Encyclopedia', 'Worl...
# 3  ['Oppression', 'Historical Awareness', 'Moral ...
# 4  ['Holocaust', 'Genocide', 'World War II', 'His...
#
#                           original_query google_translate 4o_mini_translate  \
# 0  how many people died in the holocaust              NaN               NaN
# 1                      armenian genocide              NaN               NaN
# 2                 holocaust encyclopedia              NaN               NaN
# 3                    first they came for              NaN               NaN
# 4                              holocaust              NaN               NaN
#
#                                        ushmm_article  \
# 0  #How Many People did the Nazis Murder? | Holoc...
# 1  #The Armenian Genocide (1915-16): Overview | H...
# 2  #Introduction to the Holocaust: What was the H...
# 3  #Martin Niemöller: "First they came for the So...
# 4  #Introduction to the Holocaust: What was the H...
#
#                                  chatgpt-4o-response  \
# 0  Approximately 6 million Jews were killed durin...
# 1  The Armenian Genocide was the systematic mass ...
# 2  The Holocaust Encyclopedia is a comprehensive ...
# 3  The phrase "First they came for..." is the ope...
# 4  The Holocaust was the systematic, state-sponso...
#
#                                      Gemini Response  \
# 0  Historians estimate that the Nazis murdered ap...
# 1  The Armenian Genocide was the systematic destr...
# 2  The Holocaust Encyclopedia is a comprehensive ...
# 3  "First they came for the socialists, and I did...
# 4  The Holocaust was the systematic, state-sponso...
#
#                                        Grok Response ai_overview_standalone  \
# 0  The Holocaust was a period of systematic perse...                     []
# 1  The Armenian Genocide was the systematic exter...                     []
# 2  The Holocaust Encyclopedia is a comprehensive ...                     []
# 3  "First they came ..." is the beginning of a fa...                     []
# 4  Der Holocaust war eine systematische, staatlic...                     []
#
#   comments                                  related_questions  \
# 0      NaN                                                 []
# 1      NaN                                                 []
# 2      NaN  [{'question': 'Is the Holocaust Encyclopedia c...
# 3      NaN  [{'question': 'What is the saying "first they ...
# 4      NaN  [{'question': 'Are any Holocaust survivors sti...
#
#                                          ushmm_links final_language
# 0  ['https://encyclopedia.ushmm.org/content/en/ar...        English
# 1  ['https://encyclopedia.ushmm.org/content/en/ar...        English
# 2  ['https://encyclopedia.ushmm.org/', 'https://e...        English
# 3  ['https://encyclopedia.ushmm.org/content/en/ar...        English
# 4  ['https://encyclopedia.ushmm.org/content/en/ar...        English

# %% [markdown]
# ## Tokenize Sentences.
#
# The goal of this section is to split the document into meaningful "sentences".
#
# Challenges
# 1. Some headings dont have punctuation

# %%
import pandas as pd
import re
from typing import List, Tuple

# Your existing tokenizer code (keeping it as is)
import spacy

# Compile regex patterns once
MARKDOWN_PATTERNS = [
    (re.compile(r'(\*\*|__)(.*?)\1'), r'\2'),  # Bold
    (re.compile(r'(\*|_)(.*?)\1'), r'\2'),     # Italic
    (re.compile(r'`([^`]*)`'), r'\1'),         # Inline code
    (re.compile(r'\[([^\]]+)\]\([^)]+\)'), r'\1'),  # Links
    (re.compile(r'!\[([^\]]*)\]\([^)]+\)'), r'\1'),  # Images
    (re.compile(r'^\s*>\s*', re.MULTILINE), ''),     # Blockquotes
    (re.compile(r'^\s*[-*+]\s+', re.MULTILINE), ''), # List markers
]

HEADING_PATTERN = re.compile(r'^\s*#+')
HASH_REMOVE_PATTERN = re.compile(r'^\s*#+\s*')
SENTENCE_SPLIT_PATTERN = re.compile(r'[.!?]+\s+')

def remove_markdown_fast(text):
    for pattern, replacement in MARKDOWN_PATTERNS:
        text = pattern.sub(replacement, text)
    return text.strip()

def is_markdown_heading_cached(line):
    """Cache heading detection for repeated patterns"""
    return bool(HEADING_PATTERN.match(line))

def is_short_line(line, min_sentence_length=4):
    """Check if line is shorter than threshold"""
    return len(line.strip()) < min_sentence_length

def is_short_without_punctuation(line):
    """Check if line ends without punctuation"""

    #ingore long sentences
    num_words = len(line.split())
    if num_words > 9:
        return False

    # Get last 4 characters and check if any are punctuation
    last_chars = line.rstrip()[-4:] if len(line.rstrip()) >= 4 else line.rstrip()

    # Check if any of the last characters are punctuation
    punctuation_chars = '.!?'
    return not any(char in punctuation_chars for char in last_chars)


def sentence_tokenize_document_fast(text) -> Tuple[List[str], List[bool], List[str]]:
    """
    Tokenize document and return sentences with marking information.

    Args:
        text: Input text to tokenize

    Returns:
        Tuple of (sentences, marked_for_removal_flags, removal_reasons)
    """
    # Load spaCy model once and reuse
    if not hasattr(sentence_tokenize_document_fast, 'nlp'):
        sentence_tokenize_document_fast.nlp = spacy.load("en_core_web_sm")
    nlp = sentence_tokenize_document_fast.nlp

    lines = text.split('\n')
    units = []
    marked_for_removal = []
    removal_reasons = []

    for i, line in enumerate(lines):
        stripped = line.strip()
        if not stripped:
            continue

        if is_markdown_heading_cached(stripped):
            clean = HASH_REMOVE_PATTERN.sub('', stripped)
            clean = remove_markdown_fast(clean)
            units.append(clean)

            # Check if this heading should be marked
            marked_for_removal.append(True)
            removal_reasons.append('Markdown heading')

        else:
            clean = remove_markdown_fast(stripped)
            original_line = clean  # Keep track of original line for line break detection

            try:
                doc = nlp(clean)
                sentences = [sent.text.strip() for sent in doc.sents]
            except:
                sentences = [s.strip() for s in SENTENCE_SPLIT_PATTERN.split(clean) if s.strip()]

            # Process each sentence from this line
            for j, sentence in enumerate(sentences):
                if is_short_line(sentence, min_sentence_length=4):
                    units.append(sentence)
                    marked_for_removal.append(True)
                    removal_reasons.append('Short sentence')
                elif is_short_without_punctuation(sentence):
                    units.append(sentence)
                    marked_for_removal.append(True)
                    removal_reasons.append('Sentence without punctuation')
                else:
                    units.append(sentence)
                    marked_for_removal.append(False)
                    removal_reasons.append('')

    return units, marked_for_removal, removal_reasons

def batch_process_to_sentences(df: pd.DataFrame,
                             text_columns: List[str],
                             tokenizer_func,
                             batch_size: int = 100,
                             id_col: str = 'id',
                             additional_cols: List[str] = None
                                ) -> pd.DataFrame:
    """
    Process text columns in batches and directly output long-format sentence DataFrame.
    Uses tokenizer that returns marking information.

    Args:
        df: Input DataFrame
        text_columns: List of column names containing text to process
        tokenizer_func: Function to tokenize text (should return sentences, marks, reasons)
        batch_size: Number of documents to process at once
        id_col: Name of ID column
        additional_cols: Other columns to preserve
        tokenizer)

    Returns:
        Long-form DataFrame with columns: [id_col, sentence_id, additional_cols..., source, sentence, marked_for_removal, removal_reason]
    """
    if additional_cols is None:
        additional_cols = []

    all_sentence_rows = []

    # Process each text column
    for source_col in text_columns:
        print(f"Processing {source_col}...")

        # Process this column in batches
        for i in range(0, len(df), batch_size):
            batch_df = df.iloc[i:i+batch_size]

            # Process each document in the batch
            for _, row in batch_df.iterrows():
                text = row[source_col]

                # Skip empty/null text
                if pd.isna(text) or text == '':
                    continue

                # Tokenize the text and get marking information
                sentences, marks, reasons = tokenizer_func(text)

                # Create rows for each sentence
                for sentence_id, (sentence, marked, reason) in enumerate(zip(sentences, marks, reasons), 1):
                    if sentence.strip():  # Skip empty sentences
                        sentence_row = {
                            id_col: row[id_col],
                            'sentence_id': sentence_id,
                            'source': source_col,
                            'sentence': sentence.strip(),
                            'marked_for_removal': marked,
                            'removal_reason': reason
                        }

                        # Add additional columns
                        for col in additional_cols:
                            sentence_row[col] = row[col]

                        all_sentence_rows.append(sentence_row)

            if i % min(batch_size, 10) == 0:  # At least every 10 docs
                print(f"  Processed {min(i + batch_size, len(df))}/{len(df)} documents")

    # Convert to DataFrame
    print("Creating final DataFrame...")
    result_df = pd.DataFrame(all_sentence_rows)

    # Reorder columns nicely
    if not result_df.empty:
        final_cols = [id_col, 'sentence_id'] + additional_cols + ['source', 'sentence', 'marked_for_removal', 'removal_reason']
        result_df = result_df[final_cols]

        # rename id_col to query_id
        result_df.rename(columns={id_col: 'query_id'}, inplace=True)

        #insert doc_id after 'source' where doc_id = {query_id}_{source}
        result_df.insert(2, 'doc_id', result_df.apply(lambda row: f"{row['query_id']}_{row['source']}", axis=1))

        # Print summary statistics
        if len(result_df) > 0:
            total_sentences = len(result_df)
            marked_count = result_df['marked_for_removal'].sum()
            print(f"\nProcessing complete!")
            print(f"Total sentences: {total_sentences:,}")
            print(f"Marked for removal: {marked_count:,} ({marked_count/total_sentences*100:.1f}%)")

            if marked_count > 0:
                print("\nRemoval reasons breakdown:")
                reason_counts = result_df[result_df['marked_for_removal']]['removal_reason'].value_counts()
                for reason, count in reason_counts.items():
                    print(f"  {reason}: {count:,}")

    return result_df

## Test
test_df = df[0:5].copy()

# Process with the enhanced tokenizer
result = batch_process_to_sentences(
    df=test_df,
    text_columns=['ushmm_article', 'chatgpt-4o-response',
       'Gemini Response', 'Grok Response'],
    tokenizer_func=sentence_tokenize_document_fast,
    batch_size=2,
    additional_cols=['original_query', 'location']
)

print("\nSample results:")
result[['sentence', 'marked_for_removal', 'removal_reason']].head(10)
# Out:
# Processing ushmm_article...
#   Processed 5/10 documents
#   Processed 10/10 documents
# Processing chatgpt-4o-response...
#   Processed 5/10 documents
#   Processed 10/10 documents
# Processing Gemini Response...
#   Processed 5/10 documents
#   Processed 10/10 documents
# Processing Grok Response...
#   Processed 5/10 documents
#   Processed 10/10 documents
# Creating final DataFrame...
#
# Processing complete!
# Total sentences: 1,958
# Marked for removal: 305 (15.6%)
#
# Removal reasons breakdown:
#   Markdown heading: 144
#   Sentence without punctuation: 117
#   Short sentence: 44
#
# Sample results:
#                                                                                                                                                                                                                                                                                 sentence  \
# 0                                                                                                                                                                                                                         How Many People did the Nazis Murder? | Holocaust Encyclopedia
# 1                                                                                                                                                                                                                                                                                      -
# 2                                                                                                                                                                                                                          Nazi Germany committed mass murder on an unprecedented scale.
# 3                                                                                                                                                                 Before and especially during World War II, the Nazi German regime perpetrated the Holocaust and other mass atrocities.
# 4                                                                                                                                          In the aftermath of these crimes, calculating the number of victims became important for legal, historical, ethical, and educational reasons.
# 5                                                                                                                                                                                                              The statistics below were calculated using a number of different sources.
# 6  These sources include surviving Nazi German reports and records; prewar and postwar demographic studies; records created by Jews during and after the war; documentation created by resistance groups and underground activists; as well as other available, extant archival sources.
# 7                                                                                                                                                                                                   These death statistics lay bare the enormity of the Holocaust and other Nazi crimes.
# 8                                                                                                                                                                                           They are a starting point for confronting the scale of human loss unleashed by Nazi Germany.
# 9                                                                                                                                                                                                                                          How many Jewish people died in the Holocaust?
#
#    marked_for_removal    removal_reason
# 0                True  Markdown heading
# 1                True    Short sentence
# 2               False
# 3               False
# 4               False
# 5               False
# 6               False
# 7               False
# 8               False
# 9                True  Markdown heading

# %%
#@title Sentence tokenize entire df
sent_df = batch_process_to_sentences(
    df=df,
    text_columns=['ushmm_article', 'chatgpt-4o-response',
       'Gemini Response', 'Grok Response'],
    tokenizer_func=sentence_tokenize_document_fast,
    batch_size=100,
    additional_cols=['original_query', 'location']
)
# Out:
# Processing ushmm_article...
#   Processed 100/6000 documents
#   Processed 200/6000 documents
#   Processed 300/6000 documents
#   Processed 400/6000 documents
#   Processed 500/6000 documents
#   Processed 600/6000 documents
#   Processed 700/6000 documents
#   Processed 800/6000 documents
#   Processed 900/6000 documents
#   Processed 1000/6000 documents
#   Processed 1100/6000 documents
#   Processed 1200/6000 documents
#   Processed 1300/6000 documents
#   Processed 1400/6000 documents
#   Processed 1500/6000 documents
#   Processed 1600/6000 documents
#   Processed 1700/6000 documents
#   Processed 1800/6000 documents
#   Processed 1900/6000 documents
#   Processed 2000/6000 documents
#   Processed 2100/6000 documents
#   Processed 2200/6000 documents
#   Processed 2300/6000 documents
#   Processed 2400/6000 documents
#   Processed 2500/6000 documents
#   Processed 2600/6000 documents
#   Processed 2700/6000 documents
#   Processed 2800/6000 documents
#   Processed 2900/6000 documents
#   Processed 3000/6000 documents
#   Processed 3100/6000 documents
#   Processed 3200/6000 documents
#   Processed 3300/6000 documents
#   Processed 3400/6000 documents
#   Processed 3500/6000 documents
#   Processed 3600/6000 documents
#   Processed 3700/6000 documents
#   Processed 3800/6000 documents
#   Processed 3900/6000 documents
#   Processed 4000/6000 documents
#   Processed 4100/6000 documents
#   Processed 4200/6000 documents
#   Processed 4300/6000 documents
#   Processed 4400/6000 documents
#   Processed 4500/6000 documents
#   Processed 4600/6000 documents
#   Processed 4700/6000 documents
#   Processed 4800/6000 documents
#   Processed 4900/6000 documents
#   Processed 5000/6000 documents
#   Processed 5100/6000 documents
#   Processed 5200/6000 documents
#   Processed 5300/6000 documents
#   Processed 5400/6000 documents
#   Processed 5500/6000 documents
#   Processed 5600/6000 documents
#   Processed 5700/6000 documents
#   Processed 5800/6000 documents
#   Processed 5900/6000 documents
#   Processed 6000/6000 documents
# Processing chatgpt-4o-response...
#   Processed 100/6000 documents
#   Processed 200/6000 documents
#   Processed 300/6000 documents
#   Processed 400/6000 documents
#   Processed 500/6000 documents
#   Processed 600/6000 documents
#   Processed 700/6000 documents
#   Processed 800/6000 documents
#   Processed 900/6000 documents
#   Processed 1000/6000 documents
#   Processed 1100/6000 documents
#   Processed 1200/6000 documents
#   Processed 1300/6000 documents
#   Processed 1400/6000 documents
#   Processed 1500/6000 documents
#   Processed 1600/6000 documents
#   Processed 1700/6000 documents
#   Processed 1800/6000 documents
#   Processed 1900/6000 documents
#   Processed 2000/6000 documents
#   Processed 2100/6000 documents
#   Processed 2200/6000 documents
#   Processed 2300/6000 documents
#   Processed 2400/6000 documents
#   Processed 2500/6000 documents
#   Processed 2600/6000 documents
#   Processed 2700/6000 documents
#   Processed 2800/6000 documents
#   Processed 2900/6000 documents
#   Processed 3000/6000 documents
#   Processed 3100/6000 documents
#   Processed 3200/6000 documents
#   Processed 3300/6000 documents
#   Processed 3400/6000 documents
#   Processed 3500/6000 documents
#   Processed 3600/6000 documents
#   Processed 3700/6000 documents
#   Processed 3800/6000 documents
#   Processed 3900/6000 documents
#   Processed 4000/6000 documents
#   Processed 4100/6000 documents
#   Processed 4200/6000 documents
#   Processed 4300/6000 documents
#   Processed 4400/6000 documents
#   Processed 4500/6000 documents
#   Processed 4600/6000 documents
#   Processed 4700/6000 documents
#   Processed 4800/6000 documents
#   Processed 4900/6000 documents
#   Processed 5000/6000 documents
#   Processed 5100/6000 documents
#   Processed 5200/6000 documents
#   Processed 5300/6000 documents
#   Processed 5400/6000 documents
#   Processed 5500/6000 documents
#   Processed 5600/6000 documents
#   Processed 5700/6000 documents
#   Processed 5800/6000 documents
#   Processed 5900/6000 documents
#   Processed 6000/6000 documents
# Processing Gemini Response...
#   Processed 100/6000 documents
#   Processed 200/6000 documents
#   Processed 300/6000 documents
#   Processed 400/6000 documents
#   Processed 500/6000 documents
#   Processed 600/6000 documents
#   Processed 700/6000 documents
#   Processed 800/6000 documents
#   Processed 900/6000 documents
#   Processed 1000/6000 documents
#   Processed 1100/6000 documents
#   Processed 1200/6000 documents
#   Processed 1300/6000 documents
#   Processed 1400/6000 documents
#   Processed 1500/6000 documents
#   Processed 1600/6000 documents
#   Processed 1700/6000 documents
#   Processed 1800/6000 documents
#   Processed 1900/6000 documents
#   Processed 2000/6000 documents
#   Processed 2100/6000 documents
#   Processed 2200/6000 documents
#   Processed 2300/6000 documents
#   Processed 2400/6000 documents
#   Processed 2500/6000 documents
#   Processed 2600/6000 documents
#   Processed 2700/6000 documents
#   Processed 2800/6000 documents
#   Processed 2900/6000 documents
#   Processed 3000/6000 documents
#   Processed 3100/6000 documents
#   Processed 3200/6000 documents
#   Processed 3300/6000 documents
#   Processed 3400/6000 documents
#   Processed 3500/6000 documents
#   Processed 3600/6000 documents
#   Processed 3700/6000 documents
#   Processed 3800/6000 documents
#   Processed 3900/6000 documents
#   Processed 4000/6000 documents
#   Processed 4100/6000 documents
#   Processed 4200/6000 documents
#   Processed 4300/6000 documents
#   Processed 4400/6000 documents
#   Processed 4500/6000 documents
#   Processed 4600/6000 documents
#   Processed 4700/6000 documents
#   Processed 4800/6000 documents
#   Processed 4900/6000 documents
#   Processed 5000/6000 documents
#   Processed 5100/6000 documents
#   Processed 5200/6000 documents
#   Processed 5300/6000 documents
#   Processed 5400/6000 documents
#   Processed 5500/6000 documents
#   Processed 5600/6000 documents
#   Processed 5700/6000 documents
#   Processed 5800/6000 documents
#   Processed 5900/6000 documents
#   Processed 6000/6000 documents
# Processing Grok Response...
#   Processed 100/6000 documents
#   Processed 200/6000 documents
#   Processed 300/6000 documents
#   Processed 400/6000 documents
#   Processed 500/6000 documents
#   Processed 600/6000 documents
#   Processed 700/6000 documents
#   Processed 800/6000 documents
#   Processed 900/6000 documents
#   Processed 1000/6000 documents
#   Processed 1100/6000 documents
#   Processed 1200/6000 documents
#   Processed 1300/6000 documents
#   Processed 1400/6000 documents
#   Processed 1500/6000 documents
#   Processed 1600/6000 documents
#   Processed 1700/6000 documents
#   Processed 1800/6000 documents
#   Processed 1900/6000 documents
#   Processed 2000/6000 documents
#   Processed 2100/6000 documents
#   Processed 2200/6000 documents
#   Processed 2300/6000 documents
#   Processed 2400/6000 documents
#   Processed 2500/6000 documents
#   Processed 2600/6000 documents
#   Processed 2700/6000 documents
#   Processed 2800/6000 documents
#   Processed 2900/6000 documents
#   Processed 3000/6000 documents
#   Processed 3100/6000 documents
#   Processed 3200/6000 documents
#   Processed 3300/6000 documents
#   Processed 3400/6000 documents
#   Processed 3500/6000 documents
#   Processed 3600/6000 documents
#   Processed 3700/6000 documents
#   Processed 3800/6000 documents
#   Processed 3900/6000 documents
#   Processed 4000/6000 documents
#   Processed 4100/6000 documents
#   Processed 4200/6000 documents
#   Processed 4300/6000 documents
#   Processed 4400/6000 documents
#   Processed 4500/6000 documents
#   Processed 4600/6000 documents
#   Processed 4700/6000 documents
#   Processed 4800/6000 documents
#   Processed 4900/6000 documents
#   Processed 5000/6000 documents
#   Processed 5100/6000 documents
#   Processed 5200/6000 documents
#   Processed 5300/6000 documents
#   Processed 5400/6000 documents
#   Processed 5500/6000 documents
#   Processed 5600/6000 documents
#   Processed 5700/6000 documents
#   Processed 5800/6000 documents
#   Processed 5900/6000 documents
#   Processed 6000/6000 documents
# Creating final DataFrame...
#
# Processing complete!
# Total sentences: 695,844
# Marked for removal: 181,339 (26.1%)
#
# Removal reasons breakdown:
#   Sentence without punctuation: 112,338
#   Markdown heading: 50,895
#   Short sentence: 18,106

# %%
# display full "sentence" col
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 20)  # This will show n rows

# Show all sentences marked for removal with this reason
filtered_df = sent_df[sent_df['removal_reason'] == 'Sentence without punctuation']
print(f"Total sentences with this removal reason: {len(filtered_df)}")
filtered_df
# Out:
# Total sentences with this removal reason: 112338
#         query_id  sentence_id             doc_id  \
# 22             0           23    0_ushmm_article
# 45             0           46    0_ushmm_article
# 46             0           47    0_ushmm_article
# 47             0           48    0_ushmm_article
# 48             0           49    0_ushmm_article
# ...          ...          ...                ...
# 695817       999            3  999_Grok Response
# 695819       999            5  999_Grok Response
# 695822       999            8  999_Grok Response
# 695826       999           12  999_Grok Response
# 695830       999           16  999_Grok Response
#
#                                original_query       location         source  \
# 22      how many people died in the holocaust  United States  ushmm_article
# 45      how many people died in the holocaust  United States  ushmm_article
# 46      how many people died in the holocaust  United States  ushmm_article
# 47      how many people died in the holocaust  United States  ushmm_article
# 48      how many people died in the holocaust  United States  ushmm_article
# ...                                       ...            ...            ...
# 695817                   the bielski brothers  United States  Grok Response
# 695819                   the bielski brothers  United States  Grok Response
# 695822                   the bielski brothers  United States  Grok Response
# 695826                   the bielski brothers  United States  Grok Response
# 695830                   the bielski brothers  United States  Grok Response
#
#                                              sentence  marked_for_removal  \
# 22                                      | --- | --- |                True
# 45      | Killing center | Number of Jewish victims |                True
# 46                                      | --- | --- |                True
# 47                     | Chełmno | at least 167,000 |                True
# 48                 | Belzec | approximately 435,000 |                True
# ...                                               ...                 ...
# 695817                       Here’s a brief overview:                True
# 695819                   1. Tuvia Bielski (1906-1987)                True
# 695822                   2. Asael Bielski (1908-1945)                True
# 695826                        Zus Bielski (1912-1995)                True
# 695830                       Aron Bielski (1927-2018)                True
#
#                       removal_reason
# 22      Sentence without punctuation
# 45      Sentence without punctuation
# 46      Sentence without punctuation
# 47      Sentence without punctuation
# 48      Sentence without punctuation
# ...                              ...
# 695817  Sentence without punctuation
# 695819  Sentence without punctuation
# 695822  Sentence without punctuation
# 695826  Sentence without punctuation
# 695830  Sentence without punctuation
#
# [112338 rows x 9 columns]

# %%
#@title Save Raw Sentence DF
sent_df.to_csv(f"{BASE_DIR}/all_models_sentence_tokenized_raw.csv", index=False)

# %%
# Mark Sections for Removal

import re

# Define section headers and metadata patterns to remove
section_headers = ['Critical Thinking Questions', 'Footnotes']

# Define regex patterns for metadata that typically appears at document end
metadata_patterns = [
    r'^Last Edited:\s*',           # "Last Edited: Sep 26, 2023"
    r'^Author\(s\):\s*',           # "Author(s):"
]

# pre-compile patterns for efficiency
compiled_patterns = [re.compile(pattern, re.IGNORECASE) for pattern in metadata_patterns]

def matches_metadata_pattern(sentence):
    """Check if sentence matches any metadata pattern"""
    sentence = sentence.strip()
    return any(pattern.match(sentence) for pattern in compiled_patterns)

def mark_sections_for_removal(df,
                              source_name,
                              section_headers,
                              metadata_patterns):
    """Mark entire sections for removal from end of documents"""

    # Check for section headers and metadata patterns in USHMM articles only
    df['is_section_header'] = (
        (df['source'] == 'ushmm_article') &
        (df['sentence'].isin(section_headers))
    )

    df['is_metadata'] = (
        (df['source'] == 'ushmm_article') &
        (df['sentence'].apply(matches_metadata_pattern))
    )

    # Combine both types of markers
    df['is_section_removal_marker'] = df['is_section_header'] | df['is_metadata']

    # Initialize section_to_remove column
    df['section_to_remove'] = False

    # Process each USHMM document
    ushmm_mask = df['source'] == 'ushmm_article'
    if ushmm_mask.any():
        for doc_id in df[ushmm_mask]['doc_id'].unique():
            doc_mask = (df['doc_id'] == doc_id) & (df['source'] == 'ushmm_article')
            doc_group = df[doc_mask]

            # Find first occurrence of ANY removal marker (section header OR metadata)
            marker_rows = doc_group[doc_group['is_section_removal_marker']]

            if not marker_rows.empty:
                # Get the sentence_id of the first marker
                first_marker_sentence_id = marker_rows['sentence_id'].min()

                # Mark all sentences from first marker to end of document
                max_sentence_id = doc_group['sentence_id'].max()

                # Mark rows for removal
                removal_mask = (doc_group['sentence_id'] >= first_marker_sentence_id)
                df.loc[doc_group[removal_mask].index, 'section_to_remove'] = True

                print(f"Doc {doc_id}: Found marker at sentence {first_marker_sentence_id}, marking sentences {first_marker_sentence_id}-{max_sentence_id} for removal")

                # Show what triggered the removal
                trigger_sentence = marker_rows[marker_rows['sentence_id'] == first_marker_sentence_id]['sentence'].iloc[0]
                print(f"  Triggered by: '{trigger_sentence}'")

        return df

pre_processed_df = mark_sections_for_removal(sent_df, 'ushmm_article', section_headers, metadata_patterns)
# Out:
# Doc 0_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 1_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Last Edited: Nov 7, 2024'
# Doc 2_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 3_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 4_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 5_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 6_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 7_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 8_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 9_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 10_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 11_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 12_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 13_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 14_ushmm_article: Found marker at sentence 42, marking sentences 42-50 for removal
#   Triggered by: 'Author(s):'
# Doc 15_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 16_ushmm_article: Found marker at sentence 138, marking sentences 138-145 for removal
#   Triggered by: 'Footnotes'
# Doc 17_ushmm_article: Found marker at sentence 145, marking sentences 145-152 for removal
#   Triggered by: 'Last Edited: Mar 16, 2015'
# Doc 18_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 19_ushmm_article: Found marker at sentence 83, marking sentences 83-85 for removal
#   Triggered by: 'Last Edited: Apr 17, 2023'
# Doc 20_ushmm_article: Found marker at sentence 77, marking sentences 77-83 for removal
#   Triggered by: 'Last Edited: Oct 16, 2024'
# Doc 21_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 22_ushmm_article: Found marker at sentence 52, marking sentences 52-57 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 24_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 25_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 26_ushmm_article: Found marker at sentence 256, marking sentences 256-266 for removal
#   Triggered by: 'Footnotes'
# Doc 27_ushmm_article: Found marker at sentence 77, marking sentences 77-83 for removal
#   Triggered by: 'Last Edited: Oct 16, 2024'
# Doc 28_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 31_ushmm_article: Found marker at sentence 43, marking sentences 43-44 for removal
#   Triggered by: 'Author(s):'
# Doc 32_ushmm_article: Found marker at sentence 18, marking sentences 18-25 for removal
#   Triggered by: 'Author(s):'
# Doc 33_ushmm_article: Found marker at sentence 59, marking sentences 59-63 for removal
#   Triggered by: 'Last Edited: Sep 29, 2020'
# Doc 34_ushmm_article: Found marker at sentence 125, marking sentences 125-134 for removal
#   Triggered by: 'Last Edited: Mar 3, 2021'
# Doc 35_ushmm_article: Found marker at sentence 110, marking sentences 110-119 for removal
#   Triggered by: 'Footnotes'
# Doc 36_ushmm_article: Found marker at sentence 58, marking sentences 58-67 for removal
#   Triggered by: 'Last Edited: Aug 22, 2023'
# Doc 37_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 38_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 39_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 40_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 41_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 42_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 43_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 44_ushmm_article: Found marker at sentence 59, marking sentences 59-67 for removal
#   Triggered by: 'Last Edited: Feb 22, 2023'
# Doc 45_ushmm_article: Found marker at sentence 59, marking sentences 59-63 for removal
#   Triggered by: 'Last Edited: Sep 29, 2020'
# Doc 46_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 47_ushmm_article: Found marker at sentence 110, marking sentences 110-120 for removal
#   Triggered by: 'Author(s):'
# Doc 48_ushmm_article: Found marker at sentence 70, marking sentences 70-79 for removal
#   Triggered by: 'Last Edited: Apr 26, 2023'
# Doc 49_ushmm_article: Found marker at sentence 34, marking sentences 34-39 for removal
#   Triggered by: 'Author(s):'
# Doc 50_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 51_ushmm_article: Found marker at sentence 45, marking sentences 45-51 for removal
#   Triggered by: 'Author(s):'
# Doc 52_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 53_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 54_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 55_ushmm_article: Found marker at sentence 30, marking sentences 30-36 for removal
#   Triggered by: 'Last Edited: Aug 30, 2006'
# Doc 56_ushmm_article: Found marker at sentence 50, marking sentences 50-58 for removal
#   Triggered by: 'Last Edited: Sep 30, 2021'
# Doc 57_ushmm_article: Found marker at sentence 153, marking sentences 153-183 for removal
#   Triggered by: 'Footnotes'
# Doc 58_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 59_ushmm_article: Found marker at sentence 50, marking sentences 50-50 for removal
#   Triggered by: 'Last Edited: Feb 10, 2023'
# Doc 60_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 61_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 63_ushmm_article: Found marker at sentence 34, marking sentences 34-40 for removal
#   Triggered by: 'Author(s):'
# Doc 64_ushmm_article: Found marker at sentence 59, marking sentences 59-66 for removal
#   Triggered by: 'Last Edited: Aug 3, 2021'
# Doc 65_ushmm_article: Found marker at sentence 31, marking sentences 31-37 for removal
#   Triggered by: 'Author(s):'
# Doc 67_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 68_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 69_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 70_ushmm_article: Found marker at sentence 109, marking sentences 109-111 for removal
#   Triggered by: 'Last Edited: Jul 12, 2021'
# Doc 71_ushmm_article: Found marker at sentence 65, marking sentences 65-71 for removal
#   Triggered by: 'Last Edited: Aug 7, 2017'
# Doc 72_ushmm_article: Found marker at sentence 103, marking sentences 103-108 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 73_ushmm_article: Found marker at sentence 65, marking sentences 65-71 for removal
#   Triggered by: 'Last Edited: Aug 7, 2017'
# Doc 74_ushmm_article: Found marker at sentence 119, marking sentences 119-121 for removal
#   Triggered by: 'Last Edited: Oct 2, 2020'
# Doc 75_ushmm_article: Found marker at sentence 63, marking sentences 63-74 for removal
#   Triggered by: 'Footnotes'
# Doc 76_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 77_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 78_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 79_ushmm_article: Found marker at sentence 30, marking sentences 30-36 for removal
#   Triggered by: 'Last Edited: Aug 30, 2006'
# Doc 80_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Last Edited: Nov 7, 2024'
# Doc 81_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 82_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 83_ushmm_article: Found marker at sentence 25, marking sentences 25-26 for removal
#   Triggered by: 'Author(s):'
# Doc 84_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 85_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 86_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 87_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 88_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 89_ushmm_article: Found marker at sentence 35, marking sentences 35-43 for removal
#   Triggered by: 'Last Edited: Jul 7, 2021'
# Doc 90_ushmm_article: Found marker at sentence 50, marking sentences 50-50 for removal
#   Triggered by: 'Last Edited: Feb 10, 2023'
# Doc 91_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 92_ushmm_article: Found marker at sentence 18, marking sentences 18-25 for removal
#   Triggered by: 'Author(s):'
# Doc 93_ushmm_article: Found marker at sentence 110, marking sentences 110-115 for removal
#   Triggered by: 'Last Edited: Oct 9, 2020'
# Doc 94_ushmm_article: Found marker at sentence 32, marking sentences 32-41 for removal
#   Triggered by: 'Last Edited: Jan 10, 2025'
# Doc 95_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 96_ushmm_article: Found marker at sentence 197, marking sentences 197-199 for removal
#   Triggered by: 'Last Edited: Mar 25, 2025'
# Doc 97_ushmm_article: Found marker at sentence 58, marking sentences 58-67 for removal
#   Triggered by: 'Last Edited: Aug 22, 2023'
# Doc 98_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 99_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 100_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 101_ushmm_article: Found marker at sentence 77, marking sentences 77-83 for removal
#   Triggered by: 'Last Edited: Feb 10, 2025'
# Doc 102_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 103_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 104_ushmm_article: Found marker at sentence 194, marking sentences 194-197 for removal
#   Triggered by: 'Last Edited: Mar 10, 2021'
# Doc 105_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 107_ushmm_article: Found marker at sentence 68, marking sentences 68-72 for removal
#   Triggered by: 'Author(s):'
# Doc 109_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 110_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 111_ushmm_article: Found marker at sentence 32, marking sentences 32-35 for removal
#   Triggered by: 'Last Edited: Jun 13, 2019'
# Doc 112_ushmm_article: Found marker at sentence 49, marking sentences 49-61 for removal
#   Triggered by: 'Author(s):'
# Doc 113_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 116_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 117_ushmm_article: Found marker at sentence 43, marking sentences 43-44 for removal
#   Triggered by: 'Author(s):'
# Doc 118_ushmm_article: Found marker at sentence 58, marking sentences 58-67 for removal
#   Triggered by: 'Last Edited: Aug 22, 2023'
# Doc 119_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 121_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 122_ushmm_article: Found marker at sentence 49, marking sentences 49-57 for removal
#   Triggered by: 'Last Edited: Aug 30, 2018'
# Doc 123_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 124_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 125_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 126_ushmm_article: Found marker at sentence 71, marking sentences 71-78 for removal
#   Triggered by: 'Author(s):'
# Doc 127_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 128_ushmm_article: Found marker at sentence 136, marking sentences 136-144 for removal
#   Triggered by: 'Last Edited: Apr 22, 2022'
# Doc 129_ushmm_article: Found marker at sentence 110, marking sentences 110-120 for removal
#   Triggered by: 'Author(s):'
# Doc 130_ushmm_article: Found marker at sentence 38, marking sentences 38-42 for removal
#   Triggered by: 'Author(s):'
# Doc 131_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 132_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 133_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 134_ushmm_article: Found marker at sentence 64, marking sentences 64-71 for removal
#   Triggered by: 'Author(s):'
# Doc 135_ushmm_article: Found marker at sentence 57, marking sentences 57-63 for removal
#   Triggered by: 'Last Edited: Mar 27, 2025'
# Doc 136_ushmm_article: Found marker at sentence 41, marking sentences 41-48 for removal
#   Triggered by: 'Author(s):'
# Doc 137_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 138_ushmm_article: Found marker at sentence 108, marking sentences 108-108 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 139_ushmm_article: Found marker at sentence 55, marking sentences 55-63 for removal
#   Triggered by: 'Last Edited: Aug 9, 2021'
# Doc 140_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 141_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 143_ushmm_article: Found marker at sentence 103, marking sentences 103-112 for removal
#   Triggered by: 'Last Edited: Dec 7, 2020'
# Doc 145_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 146_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 147_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Last Edited: Nov 7, 2024'
# Doc 148_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 149_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 150_ushmm_article: Found marker at sentence 124, marking sentences 124-130 for removal
#   Triggered by: 'Last Edited: May 17, 2021'
# Doc 151_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 152_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 153_ushmm_article: Found marker at sentence 207, marking sentences 207-207 for removal
#   Triggered by: 'Last Edited: Dec 3, 2024'
# Doc 154_ushmm_article: Found marker at sentence 34, marking sentences 34-40 for removal
#   Triggered by: 'Author(s):'
# Doc 155_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 156_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 157_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 158_ushmm_article: Found marker at sentence 109, marking sentences 109-125 for removal
#   Triggered by: 'Footnotes'
# Doc 160_ushmm_article: Found marker at sentence 57, marking sentences 57-63 for removal
#   Triggered by: 'Last Edited: Mar 27, 2025'
# Doc 161_ushmm_article: Found marker at sentence 50, marking sentences 50-50 for removal
#   Triggered by: 'Last Edited: Feb 10, 2023'
# Doc 162_ushmm_article: Found marker at sentence 21, marking sentences 21-22 for removal
#   Triggered by: 'Author(s):'
# Doc 163_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 164_ushmm_article: Found marker at sentence 84, marking sentences 84-89 for removal
#   Triggered by: 'Last Edited: Apr 7, 2025'
# Doc 165_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 166_ushmm_article: Found marker at sentence 45, marking sentences 45-50 for removal
#   Triggered by: 'Last Edited: Sep 17, 2020'
# Doc 167_ushmm_article: Found marker at sentence 111, marking sentences 111-113 for removal
#   Triggered by: 'Last Edited: May 14, 2021'
# Doc 168_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 169_ushmm_article: Found marker at sentence 32, marking sentences 32-34 for removal
#   Triggered by: 'Last Edited: Sep 4, 2020'
# Doc 170_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 172_ushmm_article: Found marker at sentence 38, marking sentences 38-42 for removal
#   Triggered by: 'Author(s):'
# Doc 173_ushmm_article: Found marker at sentence 150, marking sentences 150-150 for removal
#   Triggered by: 'Last Edited: Dec 17, 2021'
# Doc 175_ushmm_article: Found marker at sentence 49, marking sentences 49-57 for removal
#   Triggered by: 'Last Edited: Sep 14, 2020'
# Doc 176_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 177_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 178_ushmm_article: Found marker at sentence 21, marking sentences 21-22 for removal
#   Triggered by: 'Author(s):'
# Doc 179_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 180_ushmm_article: Found marker at sentence 109, marking sentences 109-111 for removal
#   Triggered by: 'Last Edited: Jul 12, 2021'
# Doc 181_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 182_ushmm_article: Found marker at sentence 39, marking sentences 39-39 for removal
#   Triggered by: 'Last Edited: Jan 5, 2018'
# Doc 183_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 184_ushmm_article: Found marker at sentence 40, marking sentences 40-46 for removal
#   Triggered by: 'Author(s):'
# Doc 185_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 186_ushmm_article: Found marker at sentence 85, marking sentences 85-92 for removal
#   Triggered by: 'Last Edited: Jul 24, 2023'
# Doc 187_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 188_ushmm_article: Found marker at sentence 67, marking sentences 67-74 for removal
#   Triggered by: 'Last Edited: Nov 1, 2024'
# Doc 189_ushmm_article: Found marker at sentence 103, marking sentences 103-114 for removal
#   Triggered by: 'Last Edited: Nov 3, 2023'
# Doc 190_ushmm_article: Found marker at sentence 153, marking sentences 153-183 for removal
#   Triggered by: 'Footnotes'
# Doc 191_ushmm_article: Found marker at sentence 57, marking sentences 57-65 for removal
#   Triggered by: 'Last Edited: Jul 12, 2018'
# Doc 192_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 193_ushmm_article: Found marker at sentence 70, marking sentences 70-77 for removal
#   Triggered by: 'Last Edited: Mar 8, 2018'
# Doc 194_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 195_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 196_ushmm_article: Found marker at sentence 53, marking sentences 53-59 for removal
#   Triggered by: 'Last Edited: Aug 25, 2021'
# Doc 197_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 198_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 199_ushmm_article: Found marker at sentence 20, marking sentences 20-26 for removal
#   Triggered by: 'Author(s):'
# Doc 202_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Last Edited: Nov 7, 2024'
# Doc 203_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 204_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 205_ushmm_article: Found marker at sentence 38, marking sentences 38-42 for removal
#   Triggered by: 'Author(s):'
# Doc 206_ushmm_article: Found marker at sentence 207, marking sentences 207-207 for removal
#   Triggered by: 'Last Edited: Dec 3, 2024'
# Doc 207_ushmm_article: Found marker at sentence 136, marking sentences 136-144 for removal
#   Triggered by: 'Last Edited: Apr 22, 2022'
# Doc 208_ushmm_article: Found marker at sentence 207, marking sentences 207-207 for removal
#   Triggered by: 'Last Edited: Dec 3, 2024'
# Doc 209_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 210_ushmm_article: Found marker at sentence 93, marking sentences 93-100 for removal
#   Triggered by: 'Last Edited: Jun 18, 2024'
# Doc 212_ushmm_article: Found marker at sentence 122, marking sentences 122-137 for removal
#   Triggered by: 'Footnotes'
# Doc 213_ushmm_article: Found marker at sentence 42, marking sentences 42-50 for removal
#   Triggered by: 'Author(s):'
# Doc 214_ushmm_article: Found marker at sentence 28, marking sentences 28-35 for removal
#   Triggered by: 'Author(s):'
# Doc 215_ushmm_article: Found marker at sentence 30, marking sentences 30-36 for removal
#   Triggered by: 'Last Edited: Aug 30, 2006'
# Doc 218_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 219_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 220_ushmm_article: Found marker at sentence 65, marking sentences 65-71 for removal
#   Triggered by: 'Last Edited: Aug 7, 2017'
# Doc 221_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 222_ushmm_article: Found marker at sentence 72, marking sentences 72-79 for removal
#   Triggered by: 'Author(s):'
# Doc 223_ushmm_article: Found marker at sentence 58, marking sentences 58-64 for removal
#   Triggered by: 'Author(s):'
# Doc 225_ushmm_article: Found marker at sentence 153, marking sentences 153-183 for removal
#   Triggered by: 'Footnotes'
# Doc 227_ushmm_article: Found marker at sentence 59, marking sentences 59-63 for removal
#   Triggered by: 'Last Edited: Sep 29, 2020'
# Doc 229_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 230_ushmm_article: Found marker at sentence 32, marking sentences 32-35 for removal
#   Triggered by: 'Last Edited: Jun 13, 2019'
# Doc 231_ushmm_article: Found marker at sentence 39, marking sentences 39-44 for removal
#   Triggered by: 'Author(s):'
# Doc 232_ushmm_article: Found marker at sentence 22, marking sentences 22-30 for removal
#   Triggered by: 'Last Edited: Mar 19, 2021'
# Doc 233_ushmm_article: Found marker at sentence 67, marking sentences 67-74 for removal
#   Triggered by: 'Last Edited: Nov 1, 2024'
# Doc 234_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 235_ushmm_article: Found marker at sentence 32, marking sentences 32-41 for removal
#   Triggered by: 'Last Edited: Sep 8, 2023'
# Doc 237_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 239_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 240_ushmm_article: Found marker at sentence 50, marking sentences 50-50 for removal
#   Triggered by: 'Last Edited: Feb 10, 2023'
# Doc 242_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 243_ushmm_article: Found marker at sentence 22, marking sentences 22-30 for removal
#   Triggered by: 'Author(s):'
# Doc 244_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 245_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 246_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 247_ushmm_article: Found marker at sentence 45, marking sentences 45-50 for removal
#   Triggered by: 'Last Edited: Nov 5, 2024'
# Doc 248_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 249_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 250_ushmm_article: Found marker at sentence 35, marking sentences 35-39 for removal
#   Triggered by: 'Author(s):'
# Doc 252_ushmm_article: Found marker at sentence 28, marking sentences 28-35 for removal
#   Triggered by: 'Author(s):'
# Doc 254_ushmm_article: Found marker at sentence 145, marking sentences 145-152 for removal
#   Triggered by: 'Last Edited: Mar 16, 2015'
# Doc 255_ushmm_article: Found marker at sentence 30, marking sentences 30-37 for removal
#   Triggered by: 'Last Edited: Nov 22, 2024'
# Doc 258_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 259_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 260_ushmm_article: Found marker at sentence 82, marking sentences 82-91 for removal
#   Triggered by: 'Last Edited: Jun 22, 2021'
# Doc 261_ushmm_article: Found marker at sentence 33, marking sentences 33-39 for removal
#   Triggered by: 'Author(s):'
# Doc 262_ushmm_article: Found marker at sentence 32, marking sentences 32-41 for removal
#   Triggered by: 'Last Edited: Jan 10, 2025'
# Doc 264_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 265_ushmm_article: Found marker at sentence 67, marking sentences 67-74 for removal
#   Triggered by: 'Last Edited: Nov 1, 2024'
# Doc 266_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 268_ushmm_article: Found marker at sentence 246, marking sentences 246-255 for removal
#   Triggered by: 'Footnotes'
# Doc 269_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 270_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 271_ushmm_article: Found marker at sentence 42, marking sentences 42-48 for removal
#   Triggered by: 'Last Edited: Sep 17, 2018'
# Doc 272_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 273_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 274_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 275_ushmm_article: Found marker at sentence 23, marking sentences 23-29 for removal
#   Triggered by: 'Author(s):'
# Doc 277_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 278_ushmm_article: Found marker at sentence 145, marking sentences 145-152 for removal
#   Triggered by: 'Last Edited: Mar 16, 2015'
# Doc 279_ushmm_article: Found marker at sentence 92, marking sentences 92-96 for removal
#   Triggered by: 'Author(s):'
# Doc 280_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 281_ushmm_article: Found marker at sentence 98, marking sentences 98-112 for removal
#   Triggered by: 'Footnotes'
# Doc 282_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 283_ushmm_article: Found marker at sentence 101, marking sentences 101-111 for removal
#   Triggered by: 'Last Edited: Dec 18, 2019'
# Doc 284_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 286_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 288_ushmm_article: Found marker at sentence 63, marking sentences 63-74 for removal
#   Triggered by: 'Footnotes'
# Doc 289_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 290_ushmm_article: Found marker at sentence 44, marking sentences 44-52 for removal
#   Triggered by: 'Author(s):'
# Doc 291_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 292_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 293_ushmm_article: Found marker at sentence 34, marking sentences 34-39 for removal
#   Triggered by: 'Author(s):'
# Doc 294_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 295_ushmm_article: Found marker at sentence 81, marking sentences 81-88 for removal
#   Triggered by: 'Author(s):'
# Doc 297_ushmm_article: Found marker at sentence 54, marking sentences 54-54 for removal
#   Triggered by: 'Last Edited: Jul 31, 2019'
# Doc 298_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 299_ushmm_article: Found marker at sentence 207, marking sentences 207-207 for removal
#   Triggered by: 'Last Edited: Dec 3, 2024'
# Doc 301_ushmm_article: Found marker at sentence 45, marking sentences 45-51 for removal
#   Triggered by: 'Author(s):'
# Doc 302_ushmm_article: Found marker at sentence 110, marking sentences 110-115 for removal
#   Triggered by: 'Last Edited: Oct 9, 2020'
# Doc 303_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 304_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Last Edited: Nov 7, 2024'
# Doc 305_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 306_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 307_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 308_ushmm_article: Found marker at sentence 54, marking sentences 54-59 for removal
#   Triggered by: 'Last Edited: Feb 7, 2025'
# Doc 309_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 310_ushmm_article: Found marker at sentence 87, marking sentences 87-95 for removal
#   Triggered by: 'Last Edited: Oct 7, 2020'
# Doc 311_ushmm_article: Found marker at sentence 199, marking sentences 199-199 for removal
#   Triggered by: 'Last Edited: Apr 15, 2022'
# Doc 312_ushmm_article: Found marker at sentence 42, marking sentences 42-50 for removal
#   Triggered by: 'Author(s):'
# Doc 313_ushmm_article: Found marker at sentence 25, marking sentences 25-30 for removal
#   Triggered by: 'Author(s):'
# Doc 314_ushmm_article: Found marker at sentence 110, marking sentences 110-119 for removal
#   Triggered by: 'Footnotes'
# Doc 315_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 317_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 318_ushmm_article: Found marker at sentence 58, marking sentences 58-64 for removal
#   Triggered by: 'Author(s):'
# Doc 319_ushmm_article: Found marker at sentence 32, marking sentences 32-41 for removal
#   Triggered by: 'Last Edited: Jan 10, 2025'
# Doc 321_ushmm_article: Found marker at sentence 210, marking sentences 210-223 for removal
#   Triggered by: 'Footnotes'
# Doc 322_ushmm_article: Found marker at sentence 83, marking sentences 83-85 for removal
#   Triggered by: 'Last Edited: Apr 17, 2023'
# Doc 323_ushmm_article: Found marker at sentence 42, marking sentences 42-50 for removal
#   Triggered by: 'Author(s):'
# Doc 324_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 325_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Sep 7, 2023'
# Doc 326_ushmm_article: Found marker at sentence 33, marking sentences 33-39 for removal
#   Triggered by: 'Last Edited: Sep 25, 2024'
# Doc 327_ushmm_article: Found marker at sentence 70, marking sentences 70-79 for removal
#   Triggered by: 'Last Edited: Apr 26, 2023'
# Doc 328_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 329_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 331_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 332_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 333_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 334_ushmm_article: Found marker at sentence 35, marking sentences 35-39 for removal
#   Triggered by: 'Author(s):'
# Doc 335_ushmm_article: Found marker at sentence 43, marking sentences 43-50 for removal
#   Triggered by: 'Last Edited: Jul 22, 2021'
# Doc 336_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 337_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 338_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 339_ushmm_article: Found marker at sentence 109, marking sentences 109-125 for removal
#   Triggered by: 'Footnotes'
# Doc 340_ushmm_article: Found marker at sentence 29, marking sentences 29-31 for removal
#   Triggered by: 'Last Edited: Nov 26, 2019'
# Doc 341_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 343_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 345_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 346_ushmm_article: Found marker at sentence 56, marking sentences 56-65 for removal
#   Triggered by: 'Author(s):'
# Doc 347_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 348_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 350_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 352_ushmm_article: Found marker at sentence 138, marking sentences 138-145 for removal
#   Triggered by: 'Footnotes'
# Doc 353_ushmm_article: Found marker at sentence 25, marking sentences 25-26 for removal
#   Triggered by: 'Author(s):'
# Doc 354_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 355_ushmm_article: Found marker at sentence 59, marking sentences 59-60 for removal
#   Triggered by: 'Author(s):'
# Doc 356_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 357_ushmm_article: Found marker at sentence 53, marking sentences 53-59 for removal
#   Triggered by: 'Last Edited: Aug 25, 2021'
# Doc 358_ushmm_article: Found marker at sentence 45, marking sentences 45-50 for removal
#   Triggered by: 'Last Edited: Nov 5, 2024'
# Doc 359_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 360_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 361_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 362_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 364_ushmm_article: Found marker at sentence 61, marking sentences 61-67 for removal
#   Triggered by: 'Author(s):'
# Doc 365_ushmm_article: Found marker at sentence 22, marking sentences 22-30 for removal
#   Triggered by: 'Last Edited: Mar 19, 2021'
# Doc 366_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 367_ushmm_article: Found marker at sentence 63, marking sentences 63-74 for removal
#   Triggered by: 'Footnotes'
# Doc 368_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 369_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 370_ushmm_article: Found marker at sentence 153, marking sentences 153-183 for removal
#   Triggered by: 'Footnotes'
# Doc 371_ushmm_article: Found marker at sentence 82, marking sentences 82-92 for removal
#   Triggered by: 'Footnotes'
# Doc 374_ushmm_article: Found marker at sentence 110, marking sentences 110-115 for removal
#   Triggered by: 'Last Edited: Oct 9, 2020'
# Doc 375_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 376_ushmm_article: Found marker at sentence 145, marking sentences 145-152 for removal
#   Triggered by: 'Last Edited: Mar 16, 2015'
# Doc 377_ushmm_article: Found marker at sentence 210, marking sentences 210-223 for removal
#   Triggered by: 'Footnotes'
# Doc 379_ushmm_article: Found marker at sentence 56, marking sentences 56-62 for removal
#   Triggered by: 'Last Edited: Jul 16, 2021'
# Doc 380_ushmm_article: Found marker at sentence 34, marking sentences 34-39 for removal
#   Triggered by: 'Author(s):'
# Doc 381_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 382_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 383_ushmm_article: Found marker at sentence 32, marking sentences 32-39 for removal
#   Triggered by: 'Last Edited: Aug 19, 2021'
# Doc 384_ushmm_article: Found marker at sentence 42, marking sentences 42-48 for removal
#   Triggered by: 'Last Edited: Sep 17, 2018'
# Doc 385_ushmm_article: Found marker at sentence 59, marking sentences 59-63 for removal
#   Triggered by: 'Last Edited: Sep 29, 2020'
# Doc 386_ushmm_article: Found marker at sentence 29, marking sentences 29-31 for removal
#   Triggered by: 'Last Edited: Nov 26, 2019'
# Doc 387_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 388_ushmm_article: Found marker at sentence 138, marking sentences 138-145 for removal
#   Triggered by: 'Footnotes'
# Doc 389_ushmm_article: Found marker at sentence 138, marking sentences 138-145 for removal
#   Triggered by: 'Footnotes'
# Doc 390_ushmm_article: Found marker at sentence 38, marking sentences 38-42 for removal
#   Triggered by: 'Author(s):'
# Doc 391_ushmm_article: Found marker at sentence 166, marking sentences 166-167 for removal
#   Triggered by: 'Author(s):'
# Doc 392_ushmm_article: Found marker at sentence 42, marking sentences 42-50 for removal
#   Triggered by: 'Author(s):'
# Doc 393_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 395_ushmm_article: Found marker at sentence 42, marking sentences 42-50 for removal
#   Triggered by: 'Author(s):'
# Doc 396_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 398_ushmm_article: Found marker at sentence 70, marking sentences 70-79 for removal
#   Triggered by: 'Last Edited: Apr 26, 2023'
# Doc 400_ushmm_article: Found marker at sentence 77, marking sentences 77-84 for removal
#   Triggered by: 'Author(s):'
# Doc 401_ushmm_article: Found marker at sentence 77, marking sentences 77-83 for removal
#   Triggered by: 'Last Edited: Oct 16, 2024'
# Doc 402_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 403_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 404_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 405_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 406_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 407_ushmm_article: Found marker at sentence 59, marking sentences 59-63 for removal
#   Triggered by: 'Last Edited: Sep 29, 2020'
# Doc 408_ushmm_article: Found marker at sentence 59, marking sentences 59-60 for removal
#   Triggered by: 'Author(s):'
# Doc 409_ushmm_article: Found marker at sentence 15, marking sentences 15-23 for removal
#   Triggered by: 'Author(s):'
# Doc 411_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 412_ushmm_article: Found marker at sentence 45, marking sentences 45-51 for removal
#   Triggered by: 'Author(s):'
# Doc 413_ushmm_article: Found marker at sentence 8, marking sentences 8-13 for removal
#   Triggered by: 'Author(s):'
# Doc 414_ushmm_article: Found marker at sentence 53, marking sentences 53-59 for removal
#   Triggered by: 'Last Edited: Aug 25, 2021'
# Doc 415_ushmm_article: Found marker at sentence 41, marking sentences 41-47 for removal
#   Triggered by: 'Author(s):'
# Doc 416_ushmm_article: Found marker at sentence 179, marking sentences 179-202 for removal
#   Triggered by: 'Footnotes'
# Doc 417_ushmm_article: Found marker at sentence 65, marking sentences 65-71 for removal
#   Triggered by: 'Last Edited: Aug 7, 2017'
# Doc 418_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 419_ushmm_article: Found marker at sentence 103, marking sentences 103-103 for removal
#   Triggered by: 'Last Edited: Dec 15, 2022'
# Doc 420_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 421_ushmm_article: Found marker at sentence 35, marking sentences 35-39 for removal
#   Triggered by: 'Author(s):'
# Doc 422_ushmm_article: Found marker at sentence 53, marking sentences 53-63 for removal
#   Triggered by: 'Footnotes'
# Doc 423_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 425_ushmm_article: Found marker at sentence 34, marking sentences 34-40 for removal
#   Triggered by: 'Author(s):'
# Doc 427_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 428_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 429_ushmm_article: Found marker at sentence 66, marking sentences 66-71 for removal
#   Triggered by: 'Last Edited: Jan 2, 2025'
# Doc 430_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 431_ushmm_article: Found marker at sentence 27, marking sentences 27-32 for removal
#   Triggered by: 'Author(s):'
# Doc 433_ushmm_article: Found marker at sentence 89, marking sentences 89-97 for removal
#   Triggered by: 'Footnotes'
# Doc 434_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 436_ushmm_article: Found marker at sentence 42, marking sentences 42-48 for removal
#   Triggered by: 'Last Edited: Sep 17, 2018'
# Doc 437_ushmm_article: Found marker at sentence 91, marking sentences 91-101 for removal
#   Triggered by: 'Last Edited: Apr 11, 2021'
# Doc 438_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 439_ushmm_article: Found marker at sentence 21, marking sentences 21-22 for removal
#   Triggered by: 'Author(s):'
# ...
#   Triggered by: 'Last Edited: Mar 27, 2025'
# Doc 5723_ushmm_article: Found marker at sentence 68, marking sentences 68-74 for removal
#   Triggered by: 'Last Edited: Jun 11, 2021'
# Doc 5724_ushmm_article: Found marker at sentence 89, marking sentences 89-97 for removal
#   Triggered by: 'Footnotes'
# Doc 5725_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 5726_ushmm_article: Found marker at sentence 37, marking sentences 37-42 for removal
#   Triggered by: 'Author(s):'
# Doc 5727_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 5728_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 5729_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 5731_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 5732_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 5733_ushmm_article: Found marker at sentence 41, marking sentences 41-44 for removal
#   Triggered by: 'Last Edited: Sep 17, 2018'
# Doc 5734_ushmm_article: Found marker at sentence 43, marking sentences 43-45 for removal
#   Triggered by: 'Last Edited: Jun 18, 2024'
# Doc 5735_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 5736_ushmm_article: Found marker at sentence 33, marking sentences 33-39 for removal
#   Triggered by: 'Author(s):'
# Doc 5737_ushmm_article: Found marker at sentence 87, marking sentences 87-95 for removal
#   Triggered by: 'Last Edited: Oct 7, 2020'
# Doc 5738_ushmm_article: Found marker at sentence 52, marking sentences 52-57 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 5739_ushmm_article: Found marker at sentence 63, marking sentences 63-67 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 5740_ushmm_article: Found marker at sentence 30, marking sentences 30-36 for removal
#   Triggered by: 'Last Edited: Aug 30, 2006'
# Doc 5741_ushmm_article: Found marker at sentence 40, marking sentences 40-46 for removal
#   Triggered by: 'Author(s):'
# Doc 5742_ushmm_article: Found marker at sentence 50, marking sentences 50-50 for removal
#   Triggered by: 'Last Edited: Feb 10, 2023'
# Doc 5743_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 5744_ushmm_article: Found marker at sentence 195, marking sentences 195-204 for removal
#   Triggered by: 'Footnotes'
# Doc 5745_ushmm_article: Found marker at sentence 41, marking sentences 41-47 for removal
#   Triggered by: 'Author(s):'
# Doc 5746_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 5747_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 5748_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 5750_ushmm_article: Found marker at sentence 81, marking sentences 81-87 for removal
#   Triggered by: 'Last Edited: Sep 30, 2024'
# Doc 5751_ushmm_article: Found marker at sentence 45, marking sentences 45-51 for removal
#   Triggered by: 'Author(s):'
# Doc 5754_ushmm_article: Found marker at sentence 194, marking sentences 194-197 for removal
#   Triggered by: 'Last Edited: Mar 10, 2021'
# Doc 5755_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 5757_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 5758_ushmm_article: Found marker at sentence 36, marking sentences 36-44 for removal
#   Triggered by: 'Last Edited: Dec 8, 2020'
# Doc 5759_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 5760_ushmm_article: Found marker at sentence 81, marking sentences 81-91 for removal
#   Triggered by: 'Last Edited: Jun 27, 2019'
# Doc 5761_ushmm_article: Found marker at sentence 81, marking sentences 81-91 for removal
#   Triggered by: 'Last Edited: Jun 27, 2019'
# Doc 5762_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 5764_ushmm_article: Found marker at sentence 19, marking sentences 19-24 for removal
#   Triggered by: 'Author(s):'
# Doc 5765_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 5766_ushmm_article: Found marker at sentence 34, marking sentences 34-39 for removal
#   Triggered by: 'Author(s):'
# Doc 5781_ushmm_article: Found marker at sentence 317, marking sentences 317-323 for removal
#   Triggered by: 'Footnotes'
# Doc 5783_ushmm_article: Found marker at sentence 59, marking sentences 59-63 for removal
#   Triggered by: 'Last Edited: Sep 29, 2020'
# Doc 5784_ushmm_article: Found marker at sentence 59, marking sentences 59-63 for removal
#   Triggered by: 'Last Edited: Sep 29, 2020'
# Doc 5785_ushmm_article: Found marker at sentence 63, marking sentences 63-74 for removal
#   Triggered by: 'Footnotes'
# Doc 5787_ushmm_article: Found marker at sentence 11, marking sentences 11-19 for removal
#   Triggered by: 'Author(s):'
# Doc 5788_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 5789_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 5790_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 5791_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 5792_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 5793_ushmm_article: Found marker at sentence 32, marking sentences 32-36 for removal
#   Triggered by: 'Author(s):'
# Doc 5794_ushmm_article: Found marker at sentence 73, marking sentences 73-73 for removal
#   Triggered by: 'Last Edited: Jul 2, 2021'
# Doc 5795_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Author(s):'
# Doc 5798_ushmm_article: Found marker at sentence 87, marking sentences 87-95 for removal
#   Triggered by: 'Last Edited: Oct 7, 2020'
# Doc 5799_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 5805_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Last Edited: Nov 7, 2024'
# Doc 5807_ushmm_article: Found marker at sentence 103, marking sentences 103-112 for removal
#   Triggered by: 'Last Edited: Dec 7, 2020'
# Doc 5808_ushmm_article: Found marker at sentence 35, marking sentences 35-43 for removal
#   Triggered by: 'Author(s):'
# Doc 5809_ushmm_article: Found marker at sentence 43, marking sentences 43-44 for removal
#   Triggered by: 'Author(s):'
# Doc 5810_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 5811_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 5812_ushmm_article: Found marker at sentence 304, marking sentences 304-318 for removal
#   Triggered by: 'Footnotes'
# Doc 5813_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 5814_ushmm_article: Found marker at sentence 99, marking sentences 99-106 for removal
#   Triggered by: 'Footnotes'
# Doc 5816_ushmm_article: Found marker at sentence 32, marking sentences 32-41 for removal
#   Triggered by: 'Last Edited: Jan 10, 2025'
# Doc 5818_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 5819_ushmm_article: Found marker at sentence 28, marking sentences 28-35 for removal
#   Triggered by: 'Author(s):'
# Doc 5820_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 5821_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 5822_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 5823_ushmm_article: Found marker at sentence 84, marking sentences 84-89 for removal
#   Triggered by: 'Last Edited: Apr 7, 2025'
# Doc 5824_ushmm_article: Found marker at sentence 256, marking sentences 256-266 for removal
#   Triggered by: 'Footnotes'
# Doc 5825_ushmm_article: Found marker at sentence 41, marking sentences 41-44 for removal
#   Triggered by: 'Last Edited: Sep 17, 2018'
# Doc 5827_ushmm_article: Found marker at sentence 16, marking sentences 16-21 for removal
#   Triggered by: 'Author(s):'
# Doc 5841_ushmm_article: Found marker at sentence 317, marking sentences 317-323 for removal
#   Triggered by: 'Footnotes'
# Doc 5842_ushmm_article: Found marker at sentence 229, marking sentences 229-252 for removal
#   Triggered by: 'Footnotes'
# Doc 5846_ushmm_article: Found marker at sentence 17, marking sentences 17-24 for removal
#   Triggered by: 'Author(s):'
# Doc 5847_ushmm_article: Found marker at sentence 29, marking sentences 29-34 for removal
#   Triggered by: 'Author(s):'
# Doc 5848_ushmm_article: Found marker at sentence 30, marking sentences 30-36 for removal
#   Triggered by: 'Last Edited: Aug 30, 2006'
# Doc 5849_ushmm_article: Found marker at sentence 146, marking sentences 146-146 for removal
#   Triggered by: 'Last Edited: Jul 8, 2021'
# Doc 5851_ushmm_article: Found marker at sentence 65, marking sentences 65-71 for removal
#   Triggered by: 'Last Edited: Aug 7, 2017'
# Doc 5852_ushmm_article: Found marker at sentence 57, marking sentences 57-58 for removal
#   Triggered by: 'Author(s):'
# Doc 5862_ushmm_article: Found marker at sentence 177, marking sentences 177-202 for removal
#   Triggered by: 'Footnotes'
# Doc 5863_ushmm_article: Found marker at sentence 51, marking sentences 51-60 for removal
#   Triggered by: 'Last Edited: Apr 3, 2025'
# Doc 5864_ushmm_article: Found marker at sentence 39, marking sentences 39-44 for removal
#   Triggered by: 'Author(s):'
# Doc 5865_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 5866_ushmm_article: Found marker at sentence 65, marking sentences 65-71 for removal
#   Triggered by: 'Last Edited: Aug 7, 2017'
# Doc 5867_ushmm_article: Found marker at sentence 40, marking sentences 40-48 for removal
#   Triggered by: 'Last Edited: Sep 20, 2019'
# Doc 5868_ushmm_article: Found marker at sentence 274, marking sentences 274-306 for removal
#   Triggered by: 'Footnotes'
# Doc 5869_ushmm_article: Found marker at sentence 97, marking sentences 97-106 for removal
#   Triggered by: 'Last Edited: Oct 18, 2019'
# Doc 5872_ushmm_article: Found marker at sentence 258, marking sentences 258-273 for removal
#   Triggered by: 'Footnotes'
# Doc 5873_ushmm_article: Found marker at sentence 195, marking sentences 195-204 for removal
#   Triggered by: 'Footnotes'
# Doc 5874_ushmm_article: Found marker at sentence 45, marking sentences 45-51 for removal
#   Triggered by: 'Author(s):'
# Doc 5875_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 5876_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 5889_ushmm_article: Found marker at sentence 82, marking sentences 82-98 for removal
#   Triggered by: 'Footnotes'
# Doc 5890_ushmm_article: Found marker at sentence 68, marking sentences 68-74 for removal
#   Triggered by: 'Last Edited: Jun 11, 2021'
# Doc 5894_ushmm_article: Found marker at sentence 103, marking sentences 103-108 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 5895_ushmm_article: Found marker at sentence 25, marking sentences 25-26 for removal
#   Triggered by: 'Author(s):'
# Doc 5898_ushmm_article: Found marker at sentence 84, marking sentences 84-89 for removal
#   Triggered by: 'Last Edited: Apr 7, 2025'
# Doc 5900_ushmm_article: Found marker at sentence 77, marking sentences 77-97 for removal
#   Triggered by: 'Footnotes'
# Doc 5901_ushmm_article: Found marker at sentence 128, marking sentences 128-128 for removal
#   Triggered by: 'Last Edited: Nov 14, 2024'
# Doc 5910_ushmm_article: Found marker at sentence 256, marking sentences 256-261 for removal
#   Triggered by: 'Footnotes'
# Doc 5912_ushmm_article: Found marker at sentence 103, marking sentences 103-108 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 5917_ushmm_article: Found marker at sentence 49, marking sentences 49-54 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 5927_ushmm_article: Found marker at sentence 82, marking sentences 82-87 for removal
#   Triggered by: 'Last Edited: Jan 30, 2024'
# Doc 5934_ushmm_article: Found marker at sentence 44, marking sentences 44-45 for removal
#   Triggered by: 'Author(s):'
# Doc 5936_ushmm_article: Found marker at sentence 145, marking sentences 145-152 for removal
#   Triggered by: 'Last Edited: Mar 16, 2015'
# Doc 5937_ushmm_article: Found marker at sentence 34, marking sentences 34-39 for removal
#   Triggered by: 'Author(s):'
# Doc 5938_ushmm_article: Found marker at sentence 110, marking sentences 110-121 for removal
#   Triggered by: 'Last Edited: Jun 28, 2021'
# Doc 5941_ushmm_article: Found marker at sentence 39, marking sentences 39-39 for removal
#   Triggered by: 'Last Edited: Jan 5, 2018'
# Doc 5952_ushmm_article: Found marker at sentence 70, marking sentences 70-81 for removal
#   Triggered by: 'Last Edited: Jun 3, 2024'
# Doc 5953_ushmm_article: Found marker at sentence 62, marking sentences 62-67 for removal
#   Triggered by: 'Last Edited: Dec 4, 2019'
# Doc 5958_ushmm_article: Found marker at sentence 27, marking sentences 27-32 for removal
#   Triggered by: 'Author(s):'
# Doc 5966_ushmm_article: Found marker at sentence 60, marking sentences 60-65 for removal
#   Triggered by: 'Critical Thinking Questions'
# Doc 5971_ushmm_article: Found marker at sentence 258, marking sentences 258-273 for removal
#   Triggered by: 'Footnotes'
# Doc 5972_ushmm_article: Found marker at sentence 256, marking sentences 256-266 for removal
#   Triggered by: 'Footnotes'
# Doc 5976_ushmm_article: Found marker at sentence 22, marking sentences 22-29 for removal
#   Triggered by: 'Last Edited: Nov 7, 2024'
# Doc 5978_ushmm_article: Found marker at sentence 156, marking sentences 156-162 for removal
#   Triggered by: 'Last Edited: Nov 15, 2021'
# Doc 5979_ushmm_article: Found marker at sentence 59, marking sentences 59-66 for removal
#   Triggered by: 'Last Edited: Aug 3, 2021'
# Doc 5980_ushmm_article: Found marker at sentence 32, marking sentences 32-41 for removal
#   Triggered by: 'Last Edited: Sep 8, 2023'
# Doc 5984_ushmm_article: Found marker at sentence 31, marking sentences 31-35 for removal
#   Triggered by: 'Author(s):'
# Doc 5985_ushmm_article: Found marker at sentence 45, marking sentences 45-50 for removal
#   Triggered by: 'Last Edited: Sep 17, 2020'
# Doc 5988_ushmm_article: Found marker at sentence 34, marking sentences 34-42 for removal
#   Triggered by: 'Footnotes'
# Doc 5989_ushmm_article: Found marker at sentence 28, marking sentences 28-33 for removal
#   Triggered by: 'Author(s):'
# Doc 5990_ushmm_article: Found marker at sentence 42, marking sentences 42-50 for removal
#   Triggered by: 'Author(s):'
# Doc 5992_ushmm_article: Found marker at sentence 65, marking sentences 65-65 for removal
#   Triggered by: 'Last Edited: Nov 4, 2020'
# Doc 5999_ushmm_article: Found marker at sentence 22, marking sentences 22-30 for removal
#   Triggered by: 'Last Edited: Mar 19, 2021'

# %%
#@title Consolidate Removal Metadata


def consolidate_removal_metadata(df):
    """
    Consolidate removal metadata into a single column.
    """

    df = df.copy()

    df['marked_for_removal'] = df['marked_for_removal'] | df['section_to_remove']

    # Update removal_reason for section removals
    section_removal_mask = df['section_to_remove']

    # For rows with existing removal reasons, append "Section removal"
    existing_reason_mask = section_removal_mask & (df['removal_reason'] != '')
    df.loc[existing_reason_mask, 'removal_reason'] = df.loc[existing_reason_mask, 'removal_reason'] + '; Section removal'

    # For rows with no existing removal reason, set to "Section removal"
    no_reason_mask = section_removal_mask & (df['removal_reason'] == '')
    df.loc[no_reason_mask, 'removal_reason'] = 'Section removal'

    # Drop the temporary columns
    columns_to_drop = ['is_section_header', 'is_metadata', 'is_section_removal_marker', 'section_to_remove']
    df = df.drop(columns=columns_to_drop)

    return df

consolidated_df = consolidate_removal_metadata(pre_processed_df)

# %%
cols_to_insepct = ['sentence', 'marked_for_removal', 'removal_reason']

consolidated_df[cols_to_insepct].iloc[150:190]
# Out:
#                                                                                                                                                        sentence  \
# 150                                                                                     The Nazi German regime implemented this genocide between 1941 and 1945.
# 151                              By the end of the Holocaust, the Nazi German regime and their allies and collaborators had murdered six million European Jews.
# 152                                                                                                                              Why did the Nazis target Jews?
# 153                                                                                       The Nazis targeted Jews because the Nazis were radically antisemitic.
# 154                                                                                                This means that they were prejudiced against and hated Jews.
# ..                                                                                                                                                          ...
# 185                                                                                                                         Where did the Holocaust take place?
# 186                                                   The Holocaust was a Nazi German initiative that took place throughout German- and Axis-controlled Europe.
# 187                                                              It affected nearly all of Europe’s Jewish population, which in 1933 numbered 9 million people.
# 188                                                                 The Holocaust began in Germany after Adolf Hitler was appointed chancellor in January 1933.
# 189  Almost immediately, the Nazi German regime (which called itself the Third Reich) excluded Jews from German economic, political, social, and cultural life.
#
#      marked_for_removal    removal_reason
# 150               False
# 151               False
# 152                True  Markdown heading
# 153               False
# 154               False
# ..                  ...               ...
# 185                True  Markdown heading
# 186               False
# 187               False
# 188               False
# 189               False
#
# [40 rows x 3 columns]

# %%
#save df
consolidated_df.to_csv(f"{BASE_DIR}/all_models_sentence_tokenized_marked_for_removal.csv", index=False)

# %%
# count number of marked for removal

# %% [markdown]
# ## Clean Data

# %%
#@title Create cleaned dataframe

def cleaning_summary(og_df, clean_df) -> None:
    """Helper function to summarize cleaning process."""
    # Cleaning summary
    print(f"\nCleaning Summary:")
    print(f"Original dataframe size: {len(og_df)}")
    print(f"Cleaned dataframe size: {len(clean_df)}")
    print(f"Rows removed: {len(og_df) - len(clean_df)}")

    # Summarize removal_reason breakdown (only for removed rows)
    if 'removal_reason' in og_df.columns:
        print("\nRemoval reasons breakdown:")
        removed_rows = og_df[og_df['marked_for_removal']]
        reason_counts = removed_rows['removal_reason'].value_counts()
        for reason, count in reason_counts.items():
            print(f"  {reason}: {count:,}")

    # Print examples for each removal reason
    if 'removal_reason' in og_df.columns:
        for reason in removed_rows['removal_reason'].unique():
            if reason:
                print(f"\nExamples of '{reason}' removal:")
                examples = removed_rows[removed_rows['removal_reason'] == reason]['sentence'].head(3)
                for example in examples:
                    print(f"  - '{example[:100]}{'...' if len(example) > 100 else ''}'")

def filter_unmarked_sentences(df: pd.DataFrame,
                             helper_columns=['marked_for_removal', 'removal_reason'],
                             show_cleaning_summary=True) -> pd.DataFrame:
    """Helper function to filter out sentences marked for removal."""
    df = df.copy()

    # Remove rows marked for removal
    clean_df = df[~df['marked_for_removal']]

    # Drop helper columns
    clean_df = clean_df.drop(columns=helper_columns)

    # Cleaning summary
    if show_cleaning_summary:
        cleaning_summary(df, clean_df)  # This will work now

    return clean_df

cleaned_df = filter_unmarked_sentences(consolidated_df[consolidated_df['location'] == 'United States'])
# Out:
# Cleaning Summary:
# Original dataframe size: 136026
# Cleaned dataframe size: 103250
# Rows removed: 32776
#
# Removal reasons breakdown:
#   Sentence without punctuation: 13,002
#   Markdown heading: 9,610
#   Section removal: 3,741
#   Short sentence: 3,438
#   Sentence without punctuation; Section removal: 2,042
#   Markdown heading; Section removal: 924
#   Short sentence; Section removal: 19
#
# Examples of 'Markdown heading' removal:
#   - 'How Many People did the Nazis Murder? | Holocaust Encyclopedia'
#   - 'How many Jewish people died in the Holocaust?'
#   - 'How many non-Jewish people did the Nazis and their allies murder between 1933 and 1945?'
#
# Examples of 'Short sentence' removal:
#   - '-'
#   - '|'
#   - '|'
#
# Examples of 'Sentence without punctuation' removal:
#   - '| --- | --- |'
#   - '| Killing center | Number of Jewish victims |'
#   - '| --- | --- |'
#
# Examples of 'Markdown heading; Section removal' removal:
#   - 'Footnotes'
#   - 'Critical Thinking Questions'
#   - 'Critical Thinking Questions'
#
# Examples of 'Sentence without punctuation; Section removal' removal:
#   - 'Last Edited: Sep 26, 2023'
#   - 'Author(s):'
#   - 'United States Holocaust Memorial Museum, Washington, DC'
#
# Examples of 'Section removal' removal:
#   - 'Why is it challenging to calculate exactly the number of victims of the Holocaust?'
#   - 'Why is it important to document the events of the Holocaust?'
#   - 'Research the roles and complicity of professionals such as record keepers, photographers, and accoun...'
#
# Examples of 'Short sentence; Section removal' removal:
#   - '60.'
#   - '60.'
#   - '60.'

# %%
#@title save cleaned_df
cleaned_df.to_csv(f"{BASE_DIR}/us_sentence_tokenized_df_filtered.csv", index=False)

#note, the sentence cleaning dropped some entire documents

# %%
count_by_group(cleaned_df, group = 'source', i='doc_id')
# Out:
#                      count       mean        std  min   25%   50%   75%    max
# source
# Gemini Response      998.0  12.241483  12.247563  1.0   4.0   9.0  15.0   89.0
# Grok Response        998.0  10.854709   6.929501  1.0   6.0  10.0  14.0   44.0
# chatgpt-4o-response  998.0  14.188377   7.006415  1.0   9.0  14.0  19.0   40.0
# ushmm_article        987.0  66.909828  59.564230  1.0  29.0  51.0  79.0  349.0

# %%
# Find documents where all sentences are marked for removal
def find_completely_removed_docs(df):
    """Find documents where every sentence is marked for removal"""

    # Group by doc_id and calculate removal stats
    doc_stats = df.groupby('doc_id').agg({
        'marked_for_removal': ['count', 'sum'],
        'source': 'first'
    }).round(2)

    # Flatten column names
    doc_stats.columns = ['total_sentences', 'marked_sentences', 'source']

    # Find docs where all sentences are marked
    completely_removed = doc_stats[doc_stats['total_sentences'] == doc_stats['marked_sentences']]

    print(f"Found {len(completely_removed)} documents completely marked for removal:")
    print(completely_removed)

    return completely_removed

# Find the problematic documents
problem_docs = find_completely_removed_docs(consolidated_df[consolidated_df['location'] == 'United States'])

# Look at examples from each source
print("\n" + "="*50)
print("EXAMPLES OF COMPLETELY REMOVED DOCUMENTS:")
print("="*50)

for source in problem_docs['source'].unique():
    source_docs = problem_docs[problem_docs['source'] == source]
    print(f"\n{source.upper()} - {len(source_docs)} documents completely removed")

    # Show 2-3 examples
    sample_doc_ids = source_docs.index[:3]

    for doc_id in sample_doc_ids:
        print(f"\n--- Example: {doc_id} ---")
        doc_data = consolidated_df[consolidated_df['doc_id'] == doc_id]

        print(f"Total sentences: {len(doc_data)}")
        print(f"Removal reasons:")
        reasons = doc_data['removal_reason'].value_counts()
        for reason, count in reasons.items():
            print(f"  {reason}: {count}")

        print(f"First few sentences:")
        for i, (idx, row) in enumerate(doc_data.head(3).iterrows()):
            print(f"  {i+1}. '{row['sentence'][:80]}...' -> {row['removal_reason']}")
# Out:
# Found 19 documents completely marked for removal:
#                          total_sentences  marked_sentences  \
# doc_id
# 159_ushmm_article                     27                27
# 228_ushmm_article                      1                 1
# 256_ushmm_article                     19                19
# 342_ushmm_article                      1                 1
# 363_ushmm_article                      1                 1
# 373_ushmm_article                      1                 1
# 446_ushmm_article                      1                 1
# 534_Grok Response                      3                 3
# 534_chatgpt-4o-response                1                 1
# 534_ushmm_article                      9                 9
# 539_ushmm_article                      1                 1
# 583_Gemini Response                    1                 1
# 583_Grok Response                      9                 9
# 583_chatgpt-4o-response               22                22
# 69_Gemini Response                     2                 2
# 775_ushmm_article                     17                17
# 793_ushmm_article                     27                27
# 936_ushmm_article                      1                 1
# 973_ushmm_article                      1                 1
#
#                                       source
# doc_id
# 159_ushmm_article              ushmm_article
# 228_ushmm_article              ushmm_article
# 256_ushmm_article              ushmm_article
# 342_ushmm_article              ushmm_article
# 363_ushmm_article              ushmm_article
# 373_ushmm_article              ushmm_article
# 446_ushmm_article              ushmm_article
# 534_Grok Response              Grok Response
# 534_chatgpt-4o-response  chatgpt-4o-response
# 534_ushmm_article              ushmm_article
# 539_ushmm_article              ushmm_article
# 583_Gemini Response          Gemini Response
# 583_Grok Response              Grok Response
# 583_chatgpt-4o-response  chatgpt-4o-response
# 69_Gemini Response           Gemini Response
# 775_ushmm_article              ushmm_article
# 793_ushmm_article              ushmm_article
# 936_ushmm_article              ushmm_article
# 973_ushmm_article              ushmm_article
#
# ==================================================
# EXAMPLES OF COMPLETELY REMOVED DOCUMENTS:
# ==================================================
#
# USHMM_ARTICLE - 13 documents completely removed
#
# --- Example: 159_ushmm_article ---
# Total sentences: 27
# Removal reasons:
#   Sentence without punctuation: 18
#   Markdown heading: 5
#   Short sentence: 4
# First few sentences:
#   1. 'German annexation of the Sudetenland, 1938...' -> Markdown heading
#   2. '!...' -> Short sentence
#   3. '[German annexation of the Sudetenland, 1938 [LCID: cze71020]](https://encycloped...' -> Sentence without punctuation
#
# --- Example: 228_ushmm_article ---
# Total sentences: 1
# Removal reasons:
#   Sentence without punctuation: 1
# First few sentences:
#   1. 'Error: No main content found for https://encyclopedia.ushmm.org/en/a-z/photo...' -> Sentence without punctuation
#
# --- Example: 256_ushmm_article ---
# Total sentences: 19
# Removal reasons:
#   Sentence without punctuation: 10
#   Markdown heading: 5
#   Short sentence: 4
# First few sentences:
#   1. 'Poland 1933, Lvov indicated...' -> Markdown heading
#   2. '!...' -> Short sentence
#   3. '[Poland 1933, Lvov indicated [LCID: lvo79060]](https://encyclopedia.ushmm.org/im...' -> Sentence without punctuation
#
# GROK RESPONSE - 2 documents completely removed
#
# --- Example: 534_Grok Response ---
# Total sentences: 3
# Removal reasons:
#   Sentence without punctuation: 3
# First few sentences:
#   1. '卐 是佛教中的一个符号，称为“万字符”或“卐字”。在佛教中，它象征着吉祥、幸福和永恒。在不同的文化和宗教中，这个符号有不同的含义和用途。...' -> Sentence without punctuation
#   2. '然而，在20世纪初，纳粹德国采用了一个与此相似的符号（通常是镜像版本，称为“卍”），将其作为纳粹党的标志。由于纳粹的暴行，这个符号在许多国家和地区被视为极右翼和...' -> Sentence without punctuation
#   3. '因此，尽管卐在佛教和其他一些文化中具有正面的含义，但在现代西方社会中，它通常与负面历史事件相关联。使用这个符号时需要非常谨慎，了解其在不同背景下的含义。...' -> Sentence without punctuation
#
# --- Example: 583_Grok Response ---
# Total sentences: 9
# Removal reasons:
#   Sentence without punctuation: 8
#   Short sentence: 1
# First few sentences:
#   1. '犹太人（Yehudim）是一个具有悠久历史和丰富文化的民族。以下是一些关于犹太人的基本信息：...' -> Sentence without punctuation
#   2. '1. 起源：犹太人起源于古代的以色列地区，根据《 Torah》（犹太教的圣经）记载，他们是亚伯拉罕的后裔。...' -> Sentence without punctuation
#   3. '2. 宗教：大多数犹太人信奉犹太教，这是一种一神论宗教，强调道德和法律的遵守。犹太教的圣经称为《塔纳赫》，包括《托拉》、《先知书》和《圣录》。...' -> Sentence without punctuation
#
# CHATGPT-4O-RESPONSE - 2 documents completely removed
#
# --- Example: 534_chatgpt-4o-response ---
# Total sentences: 1
# Removal reasons:
#   Sentence without punctuation: 1
# First few sentences:
#   1. '你好！请问有什么我可以帮助你的吗？如果你有任何问题或需要信息，请随时告诉我。...' -> Sentence without punctuation
#
# --- Example: 583_chatgpt-4o-response ---
# Total sentences: 22
# Removal reasons:
#   Sentence without punctuation: 22
# First few sentences:
#   1. '“犹太人”是指属于犹太民族的群体，他们拥有共同的宗教信仰、文化背景、历史传承以及语言传统。犹太人起源于中东地区，是古代以色列人的后裔。犹太文化和宗教的核心是犹太...' -> Sentence without punctuation
#   2. '以下是一些关于犹太人的基本介绍：...' -> Sentence without punctuation
#   3. '一、宗教信仰：...' -> Sentence without punctuation
#
# GEMINI RESPONSE - 2 documents completely removed
#
# --- Example: 583_Gemini Response ---
# Total sentences: 1
# Removal reasons:
#   Sentence without punctuation: 1
# First few sentences:
#   1. '犹太人是一个民族和宗教群体，他们的历史和文化可以追溯到数千年前。犹太人分布在世界各地，拥有多元的文化和传统。...' -> Sentence without punctuation
#
# --- Example: 69_Gemini Response ---
# Total sentences: 2
# Removal reasons:
#   Sentence without punctuation: 2
# First few sentences:
#   1. 'World War II generally spanned from:...' -> Sentence without punctuation
#   2. 'September 1, 1939 – September 2, 1945...' -> Sentence without punctuation

# %% [markdown]
# ## Notes
#
# ####Removal summary
# - USHMM output contains some fragments like "-" and ">" We filtered these out.
# - The end of document has a lot of meta data, footnotes and critical questions which we decided to remove, as they might distract from the content of the article.
# - Sentence tokenization will have to be adapted for chinese and korean texts.
# - Error: No main content found for https://encyclopedia.ushmm.org/en/a-z/photo type content was removed.
#
# NOTE: perhaps we should actually keep "critical thinking questions" in.
#
# ####Challenges:
# - LLMs use a lot of lists. In a list, the subject of the sentence is missing, potentially making tone analysis problematic.
